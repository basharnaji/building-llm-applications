# %% [markdown]
# # Chapter 1

# %% [markdown]
# # LangChain examples

# %% [markdown]
# ## Sentence completion example

# %%
from langchain_anthropic import ChatAnthropic
import getpass

# %%
OPENAI_API_KEY = getpass.getpass('Enter your OPENAI_API_KEY')
# Out:
# Enter your OPENAI_API_KEY ········

# %%
llm = ChatAnthropic(anthropic_api_key=OPENAI_API_KEY,
                 model_name="claude-haiku-4-5-20251001")
llm.invoke("It's a hot day, I would like to go to the...")
# Out:
# AIMessage(content="# Where would you like to go on a hot day?\n\nHere are some popular options:\n\n**Water-based activities:**\n- Beach or lake\n- Swimming pool\n- Water park\n- River for wading\n\n**Indoor/cool places:**\n- Movie theater\n- Shopping mall with air conditioning\n- Museum\n- Library\n- Ice cream shop or café\n\n**Shaded outdoor spots:**\n- Park with trees\n- Hiking trail (early morning/evening)\n- Botanical garden\n- Outdoor market\n\n**Active options:**\n- Ice skating rink\n- Bowling alley\n- Gym with air conditioning\n\nWhat sounds appealing to you? I can help with suggestions based on what you're in the mood for!", additional_kwargs={}, response_metadata={'id': 'msg_012KRR9XSToL6cXzb7tXzTeL', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 21, 'output_tokens': 160, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--019d9dc0-d65e-7100-930f-50af44a97860-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 21, 'output_tokens': 160, 'total_tokens': 181, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})

# %% [markdown]
# ## Simple prompt

# %%
prompt_input = """Write a short message to remind users to be 
vigilant about phishing attacks."""
response = llm.invoke(prompt_input)

print(response.content)
# Out:
# # Stay Alert: Protect Yourself from Phishing
#
# Be vigilant! Phishing attacks are designed to trick you into revealing sensitive information. Here's how to stay safe:
#
# 🚨 **Watch for warning signs:**
# - Suspicious sender addresses or unexpected emails
# - Urgent requests for passwords, personal info, or payment details
# - Links or attachments from unknown sources
# - Spelling errors or unusual formatting
#
# ✅ **Best practices:**
# - Never click links or download attachments from untrusted emails
# - Verify sender identity before responding
# - Check URLs carefully—hover over links to see the real destination
# - When in doubt, contact the organization directly through official channels
# - Keep your software and security tools updated
#
# **Remember:** Legitimate companies will never ask for passwords or sensitive data via email or text.
#
# If you suspect a phishing attempt, report it and delete the message immediately.
#
# *Stay cautious. Stay secure.*

# %% [markdown]
# ## Prompt instantiated thorugh a PromptTemplate

# %%
from langchain_core.prompts import PromptTemplate

segovia_aqueduct_text = """The Aqueduct of Segovia 
(Spanish: Acueducto de Segovia) is a Roman aqueduct in Segovia, 
Spain. It was built around the first century AD to channel water 
from springs in the mountains 17 kilometres (11 mi) away to the 
city's fountains, public baths and private houses, and was in 
use until 1973. Its elevated section, with its complete arcade 
of 167 arches, is one of the best-preserved Roman aqueduct 
bridges and the foremost symbol of Segovia, as evidenced by 
its presence on the city's coat of arms. The Old Town of 
Segovia and the aqueduct, were declared a UNESCO World 
Heritage Site in 1985. As the aqueduct lacks a legible 
inscription (one was apparently located in the structure's 
attic, or top portion[citation needed]), the date of 
construction cannot be definitively determined. The general 
date of the Aqueduct's construction was long a mystery, 
although it was thought to have been during the 1st century AD, 
during the reigns of the Emperors Domitian, Nerva, and Trajan. 
At the end of the 20th century, Géza Alföldy deciphered the 
text on the dedication plaque by studying the anchors that held 
the now missing bronze letters in place. He determined that Emperor 
Domitian (AD 81–96) ordered its construction[1] and the year 98 AD
was proposed as the most likely date of completion.[2] However, 
in 2016 archeological evidence was published which points to a 
slightly later date, after 112 AD, during the government of 
Trajan or in the beginning of the government of emperor Hadrian, 
from 117 AD."""

prompt_template = PromptTemplate.from_template("""You are an 
experienced copywriter. Write a {num_words} words summary of 
the following text, using a {tone} tone: {text}""")

prompt_input = prompt_template.format(
    text=segovia_aqueduct_text, 
    num_words=20, 
    tone="knowledgeable and engaging")
response = llm.invoke(prompt_input)
print(response.content)
# Out:
# # Aqueduct of Segovia Summary
#
# Segovia's iconic Roman aqueduct, built around 98-117 AD, masterfully channeled mountain water 17km away via 167 magnificent arches, remaining functional until 1973.

# %% [markdown]
# ## Chain example

# %%
prompt_template = PromptTemplate.from_template("You are an experienced copywriter. Write a {num_words} words summary of the following text, using a {tone} tone: {text}")
llm = ChatAnthropic(anthropic_api_key=OPENAI_API_KEY,
                    model_name="claude-haiku-4-5-20251001")

chain = prompt_template | llm

# %%
response = chain.invoke({"text": segovia_aqueduct_text, 
              "num_words": 20, 
              "tone": "knowledgeable and engaging"})
print(response.content)
# Out:
# # Segovia's Iconic Roman Aqueduct
#
# Segovia's magnificent Roman aqueduct, built around first century AD, transported mountain water across 167 arches for 1,973 years—a UNESCO-protected engineering marvel.
